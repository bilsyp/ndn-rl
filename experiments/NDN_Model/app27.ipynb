# %%
import os
import gymnasium as gym
from gymnasium import spaces
import numpy as np
from stable_baselines3 import PPO
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.results_plotter import load_results, ts2xy
import matplotlib.pyplot as plt
import pandas as pd
import random
from collections import deque

# =============================================================================
# PERUBAHAN UTAMA DARI VERSI LAMA:
# 1. bitrates = [0.55, 0.95, 1.67, 3.40] → 4 opsi (240p/360p/480p/720p)
# 2. action_space = Discrete(4)
# 3. Scaling trace otomatis ke max_bitrate × 1.5 = 3.40 × 1.5 = 5.10 Mbps
# 4. Normalisasi last_exec dibagi 3.0 (n-1 = 3)
# 5. SAFE_MARGIN diturunkan ke 0.3 (lompatan antar bitrate lebih kecil)
# 6. NDN_CONGESTION_CWND diturunkan ke 3.0 (threshold disesuaikan)
# 7. Total timesteps = 500.000 langkah
# 8. Reward dinormalisasi terhadap max bitrate agar tidak bias
# =============================================================================

# --- KONSTANTA GLOBAL ---
BITRATES       = [0.55, 0.95, 1.67, 3.40]   # Mbps → 240p, 360p, 480p, 720p
MAX_BITRATE    = max(BITRATES)               # 3.40 Mbps
SCALE_TARGET   = MAX_BITRATE * 1.5          # 5.10 Mbps → headroom jaringan
NUM_ACTIONS    = len(BITRATES)              # 4


class MahimahiTraceManager:
    """
    Mengelola file trace Mahimahi (.log).
    Mengonversi timestamp (ms) menjadi Throughput (Mbps).
    Scaling otomatis ke SCALE_TARGET (max_bitrate × 1.5 = 5.10 Mbps)
    agar jaringan cukup menantang untuk 4 level resolusi.
    """
    def __init__(self, folder_path="traces_folder/mahimahi"):
        self.traces = []
        PACKET_SIZE_BITS = 1500 * 8

        if os.path.exists(folder_path):
            files = [f for f in os.listdir(folder_path) if f.endswith('.log')]
            files.sort()

            for file in files:
                path = os.path.join(folder_path, file)
                try:
                    with open(path, 'r') as f:
                        timestamps_ms = [float(line.strip()) for line in f if line.strip()]

                        if timestamps_ms:
                            throughput_mbps = []
                            current_sec = 0
                            packet_count = 0

                            for ts in timestamps_ms:
                                sec = int(ts / 1000)
                                while current_sec < sec:
                                    mbps = (packet_count * PACKET_SIZE_BITS) / 1_000_000
                                    throughput_mbps.append(mbps)
                                    packet_count = 0
                                    current_sec += 1
                                packet_count += 1

                            throughput_mbps.append((packet_count * PACKET_SIZE_BITS) / 1_000_000)

                            # -------------------------------------------------------
                            # PERUBAHAN: Scaling ke SCALE_TARGET (5.10 Mbps)
                            # Sebelumnya hardcoded 12.0 Mbps.
                            # Sekarang otomatis menyesuaikan dengan max bitrate client.
                            # Dengan SCALE_TARGET = 3.40 × 1.5 = 5.10 Mbps:
                            #   - Jaringan "bagus"  → bisa memilih 720p (3.40 Mbps)
                            #   - Jaringan "sedang" → hanya cukup untuk 480p (1.67 Mbps)
                            #   - Jaringan "drop"   → turun ke 360p atau 240p
                            # -------------------------------------------------------
                            max_tp = max(throughput_mbps) if throughput_mbps else 1
                            scale_factor = SCALE_TARGET / max_tp if max_tp > 0 else 1.0

                            scaled_mbps = [max(0.1, tp * scale_factor) for tp in throughput_mbps]

                            # Pre-smoothing ringan (window=3)
                            smoothed = pd.Series(scaled_mbps).rolling(
                                window=3, min_periods=1
                            ).mean().tolist()

                            self.traces.append({"name": file, "data": smoothed})

                except Exception as e:
                    print(f"Gagal memproses file {file}: {e}")

        if not self.traces:
            print("⚠️  traces_folder tidak ditemukan. Gunakan fallback synthetic.")
            # Fallback: throughput sintetis dengan variasi
            synthetic = [3.0 + 1.5 * np.sin(i * 0.1) for i in range(500)]
            self.traces.append({"name": "synth", "data": synthetic})

        self.active_trace = None
        self.ptr = 0

        print(f"✅ {len(self.traces)} trace dimuat. Target scaling: {SCALE_TARGET:.2f} Mbps")

    def select_random_trace(self):
        self.active_trace = random.choice(self.traces)
        self.ptr = random.randint(0, max(0, len(self.active_trace["data"]) - 110))
        return self.active_trace["name"]

    def set_trace_index(self, idx):
        self.active_trace = self.traces[idx % len(self.traces)]
        self.ptr = 0
        return self.active_trace["name"]

    def get_next_bandwidth(self):
        val = self.active_trace["data"][self.ptr]
        self.ptr = (self.ptr + 1) % len(self.active_trace["data"])
        return val


class HybridStreamingEnvNDN(gym.Env):
    """
    Hybrid ABR Environment — versi 4 bitrate (240p / 360p / 480p / 720p).

    Observation Space (7 dimensi, ternormalisasi [0,1]):
      [Buffer, Mean_TP, Last_Exec, Buffer_Safety, Volatility, CWND, RTT]

    Action Space:
      Discrete(4) → indeks 0/1/2/3 → 0.55/0.95/1.67/3.40 Mbps

    Perubahan dari versi 3-bitrate:
      - NUM_ACTIONS = 4, norm_exec dibagi 3.0
      - SCALE_TARGET = 5.10 Mbps (bukan 12 Mbps)
      - SAFE_MARGIN = 0.3 Mbps (lompatan antar level lebih kecil)
      - NDN_CONGESTION_CWND = 3.0 (lebih sensitif)
      - Reward dinormalisasi: reward_bitrate = chosen / MAX_BITRATE
    """

    def __init__(self, trace_manager):
        super(HybridStreamingEnvNDN, self).__init__()
        self.trace_manager = trace_manager

        # -------------------------------------------------------
        # PERUBAHAN UTAMA: 4 level bitrate sesuai resolusi client
        # -------------------------------------------------------
        self.bitrates = BITRATES   # [0.55, 0.95, 1.67, 3.40]

        # Observation: 7 dimensi [0,1]
        self.observation_space = spaces.Box(
            low=np.zeros(7, dtype=np.float32),
            high=np.ones(7, dtype=np.float32),
            dtype=np.float32
        )

        # -------------------------------------------------------
        # PERUBAHAN: Discrete(4) — bukan Discrete(3)
        # -------------------------------------------------------
        self.action_space = spaces.Discrete(NUM_ACTIONS)

        self.state = None
        self.max_steps = 100
        self.current_step = 0
        self.tp_history = deque(maxlen=10)

        # --- Threshold Buffer ---
        self.LOW_BUFFER_THRESHOLD   = 5.0   # detik → warning kuning
        self.PANIC_BUFFER_THRESHOLD = 3.0   # detik → panic merah (HARUS < LOW!)

        # -------------------------------------------------------
        # PERUBAHAN: SAFE_MARGIN diturunkan dari 1.5 → 0.3
        # Karena lompatan antar bitrate sekarang lebih kecil:
        #   0.55→0.95 = +0.40 Mbps
        #   0.95→1.67 = +0.72 Mbps
        #   1.67→3.40 = +1.73 Mbps
        # Margin 1.5 Mbps terlalu besar untuk 3 step pertama.
        # -------------------------------------------------------
        self.SAFE_MARGIN = 0.3   # Mbps headroom minimum untuk upgrade

        # -------------------------------------------------------
        # PERUBAHAN: NDN_CONGESTION_CWND diturunkan dari 5.0 → 3.0
        # Karena throughput operasional lebih rendah (maks ~5 Mbps),
        # CWND kritis perlu disesuaikan agar veto tetap efektif.
        # -------------------------------------------------------
        self.NDN_CONGESTION_CWND = 3.0
        self.NDN_CACHE_HIT_RTT   = 20.0

    # ------------------------------------------------------------------
    def _get_normalized_obs(self):
        buffer, mean_tp, last_exec, _, volatility, cwnd, rtt = self.state

        norm_buffer = np.clip(buffer / 30.0, 0.0, 1.0)
        norm_tp     = np.clip(mean_tp / SCALE_TARGET, 0.0, 1.0)  # dibagi 5.10

        # -------------------------------------------------------
        # PERUBAHAN: norm_exec dibagi (NUM_ACTIONS - 1) = 3.0
        # Sebelumnya dibagi 2.0 (untuk Discrete(3))
        # -------------------------------------------------------
        norm_exec = float(last_exec) / float(NUM_ACTIONS - 1)

        safety      = max(0, buffer - self.LOW_BUFFER_THRESHOLD)
        norm_safety = np.clip(safety / 20.0, 0.0, 1.0)
        norm_vol    = np.clip(volatility, 0.0, 1.0)
        norm_cwnd   = np.clip(cwnd / 100.0, 0.0, 1.0)
        norm_rtt    = np.clip(rtt / 500.0, 0.0, 1.0)

        return np.array(
            [norm_buffer, norm_tp, norm_exec, norm_safety, norm_vol, norm_cwnd, norm_rtt],
            dtype=np.float32
        )

    # ------------------------------------------------------------------
    def reset(self, seed=None, options=None):
        super().reset(seed=seed)

        if options and "trace_idx" in options:
            trace_name = self.trace_manager.set_trace_index(options["trace_idx"])
        else:
            trace_name = self.trace_manager.select_random_trace()

        initial_tp = self.trace_manager.get_next_bandwidth()

        self.tp_history.clear()
        for _ in range(self.tp_history.maxlen):
            self.tp_history.append(initial_tp)

        # State awal: buffer 15 detik, indeks 1 (360p), CWND 10, RTT 100ms
        self.state = np.array(
            [15.0, initial_tp, 1.0, 0.0, 0.0, 10.0, 100.0],
            dtype=np.float32
        )
        self.current_step = 0
        return self._get_normalized_obs(), {"trace": trace_name}

    # ------------------------------------------------------------------
    def step(self, action):
        target_idx  = int(action)
        buffer, _, current_idx, _, _, prev_cwnd, prev_rtt = self.state
        current_idx = int(current_idx)

        # 1. Update throughput & metrik jaringan
        raw_tp = self.trace_manager.get_next_bandwidth()
        self.tp_history.append(raw_tp)
        mean_tp    = np.mean(self.tp_history)
        volatility = np.std(self.tp_history) / (mean_tp + 1e-6)

        # Simulasi metrik NDN
        new_cwnd = np.clip(raw_tp * 8.0 + np.random.normal(0, 2), 2, 100)
        new_rtt  = np.clip(200.0 / (raw_tp + 0.5) + np.random.normal(0, 5), 5, 500)

        # ------------------------------------------------------------------
        # LAYER 2: NDN-AWARE DYNAMIC CONTROLLER
        # ------------------------------------------------------------------
        executed_idx = current_idx

        # Ambang buffer dinamis (makin volatil → butuh buffer lebih besar)
        dynamic_buffer_req = self.LOW_BUFFER_THRESHOLD + (volatility * 5.0)

        # A. NDN VETO — larang upgrade saat jalur macet
        is_ndn_congested = new_cwnd < self.NDN_CONGESTION_CWND
        if is_ndn_congested and target_idx > current_idx:
            target_idx = current_idx

    

        # C. UPGRADE LOGIC dengan Hysteresis & NDN Health
        elif target_idx > current_idx:
            headroom = mean_tp - self.bitrates[current_idx]
            # -------------------------------------------------------
            # PERUBAHAN: SAFE_MARGIN = 0.3 Mbps (dari 1.5 Mbps)
            # Disesuaikan dengan gap antar bitrate yang lebih kecil.
            # Kondisi RTT < 300 ms tetap dipertahankan.
            # -------------------------------------------------------
            if headroom > self.SAFE_MARGIN and buffer > dynamic_buffer_req and new_rtt < 300:
                executed_idx = current_idx + 1
            else:
                executed_idx = current_idx

        # D. DOWNGRADE — langsung eksekusi tanpa syarat
        else:
            executed_idx = target_idx

        # 2. Eksekusi & hitung stalling
        executed_idx  = np.clip(executed_idx, 0, NUM_ACTIONS - 1)
        chosen_bitrate = self.bitrates[executed_idx]

        # Simulasi DASH download
        download_time = (chosen_bitrate * 5.0) / (raw_tp + 0.1)
        stalling      = max(0, download_time - buffer)
        new_buffer    = max(0, buffer - download_time) + 5.0
        new_buffer    = min(new_buffer, 30.0)
        # Contoh modifikasi untuk mengobati AI yang buta buffer
       # FIX 2: Perbaiki reward buffer — gunakan if/elif yang benar
        if new_buffer < 3.0:          # kritis dulu
           reward_buffer = -50.0
        elif new_buffer < 5.0:        # baru warning
           reward_buffer = -20.0
        else:
           reward_buffer = 5.0       # aman
            # B. PANIC MODE — buffer kritis, paksa turun 1 level
        if buffer < self.PANIC_BUFFER_THRESHOLD:
            executed_idx = max(0, current_idx - 1)
        # ------------------------------------------------------------------
        # 3. REWARD FUNCTION
        # PERUBAHAN: reward bitrate dinormalisasi terhadap MAX_BITRATE
        # Sebelumnya: reward = float(chosen_bitrate)  → rentang 0.5–8.0
        # Sekarang:   reward = chosen/max             → rentang 0.0–1.0
        # Lalu diskalakan ×100 agar magnitude serupa dengan versi lama.
        # Ini mencegah bias karena selisih 0.55 vs 3.40 tidak sebesar
        # selisih 0.5 vs 8.0 pada versi lama.
        # ------------------------------------------------------------------
        norm_reward = (chosen_bitrate / MAX_BITRATE) * 100.0

        reward = norm_reward + reward_buffer
        if stalling > 0:
            reward -= (stalling * 50.0 + 20.0)   # penalti stalling (sama)
        if executed_idx != current_idx:
            reward -= 2.0                          # penalti fluktuasi (sama)

        # Update state (7 dimensi)
        self.state = np.array(
            [new_buffer, mean_tp, float(executed_idx), 0.0,
             volatility, new_cwnd, new_rtt],
            dtype=np.float32
        )

        self.current_step += 1
        done = self.current_step >= self.max_steps
        return self._get_normalized_obs(), reward, done, False, {
            "buffer":     new_buffer,
            "cwnd":       new_cwnd,
            "rtt":        new_rtt,
            "bitrate":    chosen_bitrate,
            "resolution": ["240p", "360p", "480p", "720p"][executed_idx],
            "raw_tp":     mean_tp,
            "volatility": volatility,
            "stalling":   stalling,
        }


# =============================================================================
def run_experiment():
    log_dir = "./rl_logs_4bitrate/"
    os.makedirs(log_dir, exist_ok=True)

    tm = MahimahiTraceManager(folder_path="traces_folder/mahimahi")
    if not tm.traces:
        return

    env = Monitor(HybridStreamingEnvNDN(tm), log_dir)

    print("=" * 60)
    print("  Volatility-Aware Hybrid ABR — 4 Bitrate (240p~720p)")
    print(f"  Bitrates : {BITRATES} Mbps")
    print(f"  TP Scale : {SCALE_TARGET:.2f} Mbps (max_bitrate × 1.5)")
    print(f"  Actions  : Discrete({NUM_ACTIONS})")
    print(f"  Training : 500,000 langkah")
    print("=" * 60)

    # -------------------------------------------------------
    # PERUBAHAN: total_timesteps = 500_000 (dari 300_000)
    # Action space lebih besar (4 vs 3) butuh lebih banyak
    # pengalaman agar agen menguasai semua transisi.
    # -------------------------------------------------------
    model = PPO(
        "MlpPolicy", env,
        verbose=1,
        learning_rate=0.00025,
        ent_coef=0.05,
        n_steps=2048,
        batch_size=64
    )

    model.learn(total_timesteps=500_000)
    model.save("hybrid_4bitrate_ndn_model_v4")
    print("✅ Pelatihan selesai. Model disimpan: hybrid_4bitrate_ndn_model_v3")

    # ------------------------------------------------------------------
    # EVALUASI per trace file
    # ------------------------------------------------------------------
    resolution_labels = ["240p", "360p", "480p", "720p"]
    colors_res        = ["blue", "green", "orange", "red"]

    for i in range(len(tm.traces)):
        obs, info = env.reset(options={"trace_idx": i})
        trace_name = info["trace"]
        history = []

        for _ in range(100):
            action, _ = model.predict(obs, deterministic=True)
            obs, reward, done, _, info_step = env.step(action)
            history.append({
                "TP":         info_step["raw_tp"],
                "Volatility": info_step["volatility"],
                "Buffer":     info_step["buffer"],
                "Bitrate":    info_step["bitrate"],
                "Resolution": info_step["resolution"],
                "Stalling":   info_step["stalling"],
            })
            if done:
                break

        df = pd.DataFrame(history)

        fig, axes = plt.subplots(3, 1, figsize=(13, 12), sharex=True)

        # --- Panel 1: Throughput vs Bitrate yang dieksekusi ---
        ax1 = axes[0]
        ax1.plot(df.index, df["TP"], label="Mean TP", color="steelblue", alpha=0.4)
        ax1.step(df.index, df["Bitrate"], label="Executed Bitrate",
                 color="crimson", linewidth=2, where="post")

        # Garis referensi tiap resolusi
        for br, label, col in zip(BITRATES, resolution_labels, colors_res):
            ax1.axhline(y=br, linestyle="--", linewidth=0.8, alpha=0.5,
                        color=col, label=f"{label} ({br} Mbps)")

        ax1.set_ylabel("Mbps")
        ax1.set_title(f"4-Bitrate Hybrid ABR: {trace_name}")
        ax1.legend(fontsize=7, ncol=3)

        # --- Panel 2: Buffer Level & Stalling ---
        ax2 = axes[1]
        ax2.fill_between(df.index, df["Buffer"], color="mediumseagreen",
                         alpha=0.3, label="Buffer (detik)")
        ax2.axhline(y=5.0, color="orange", linestyle="--",
                    linewidth=1, label="Low Buffer Threshold")
        ax2.axhline(y=3.0, color="red", linestyle="--",
                    linewidth=1, label="Panic Threshold")

        # Tandai stalling
        stall_mask = df["Stalling"] > 0
        if stall_mask.any():
            ax2.scatter(df.index[stall_mask], df["Buffer"][stall_mask],
                        color="red", zorder=5, s=30, label="Stalling Event")

        ax2.set_ylabel("Buffer (detik)")
        ax2.legend(fontsize=7)

        # --- Panel 3: Volatility ---
        ax3 = axes[2]
        ax3.plot(df.index, df["Volatility"], color="purple",
                 linestyle=":", label="Volatility (CV)")
        ax3.set_ylabel("Volatility")
        ax3.set_xlabel("Segmen")
        ax3.legend(fontsize=7)

        plt.tight_layout()
        out_path = os.path.join(log_dir, f"eval_4bitrate_{trace_name}.png")
        plt.savefig(out_path, dpi=120)
        plt.close()
        print(f"  📊 Plot disimpan: {out_path}")

        # Ringkasan statistik per trace
        res_counts = df["Resolution"].value_counts()
        avg_br     = df["Bitrate"].mean()
        total_stall = df["Stalling"].sum()
        print(f"  [{trace_name}] Avg Bitrate: {avg_br:.2f} Mbps | "
              f"Total Stalling: {total_stall:.2f}s | "
              f"Distribusi: {res_counts.to_dict()}")


if __name__ == "__main__":
    run_experiment()
# Out:
# ✅ 8 trace dimuat. Target scaling: 5.10 Mbps
# ============================================================
#   Volatility-Aware Hybrid ABR — 4 Bitrate (240p~720p)
#   Bitrates : [0.55, 0.95, 1.67, 3.4] Mbps
#   TP Scale : 5.10 Mbps (max_bitrate × 1.5)
#   Actions  : Discrete(4)
#   Training : 500,000 langkah
# ============================================================
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 3.39e+03 |
# | time/              |          |
# |    fps             | 802      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 3.5e+03      |
# | time/                   |              |
# |    fps                  | 500          |
# |    iterations           | 2            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0067115873 |
# |    clip_fraction        | 0.0041       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.000182     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.58e+05     |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00544     |
# |    value_loss           | 3.14e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 3.27e+03    |
# | time/                   |             |
# |    fps                  | 457         |
# |    iterations           | 3           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.001511933 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.00257     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.88e+05    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00143    |
# |    value_loss           | 3.47e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 3.27e+03     |
# | time/                   |              |
# |    fps                  | 439          |
# |    iterations           | 4            |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0011740013 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.00456      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.25e+05     |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00167     |
# |    value_loss           | 5.42e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 3.48e+03    |
# | time/                   |             |
# |    fps                  | 427         |
# |    iterations           | 5           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.002161437 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.026       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 2.54e+05    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00223    |
# |    value_loss           | 4.39e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 3.75e+03     |
# | time/                   |              |
# |    fps                  | 420          |
# |    iterations           | 6            |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0012209278 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.0337       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.93e+05     |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00185     |
# |    value_loss           | 5.42e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 4.14e+03    |
# | time/                   |             |
# |    fps                  | 404         |
# |    iterations           | 7           |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.008118421 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.00785     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 2.9e+05     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00801    |
# |    value_loss           | 5.27e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 4.42e+03    |
# | time/                   |             |
# |    fps                  | 373         |
# |    iterations           | 8           |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.005864558 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.0145      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 2.51e+05    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00669    |
# |    value_loss           | 5.84e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 4.71e+03     |
# | time/                   |              |
# |    fps                  | 363          |
# |    iterations           | 9            |
# |    time_elapsed         | 50           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0002834849 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | 0.03         |
# |    learning_rate        | 0.00025      |
# |    loss                 | 3.45e+05     |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.000807    |
# |    value_loss           | 7.28e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 4.94e+03     |
# | time/                   |              |
# |    fps                  | 346          |
# |    iterations           | 10           |
# |    time_elapsed         | 59           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0005201412 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | 0.0574       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 3.1e+05      |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00123     |
# |    value_loss           | 6.31e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 4.75e+03     |
# | time/                   |              |
# |    fps                  | 338          |
# |    iterations           | 11           |
# |    time_elapsed         | 66           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0010283196 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | 0.0267       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 4.57e+05     |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00181     |
# |    value_loss           | 7.76e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 4.86e+03     |
# | time/                   |              |
# |    fps                  | 334          |
# |    iterations           | 12           |
# |    time_elapsed         | 73           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0004268047 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | 0.0419       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 3.04e+05     |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.000595    |
# |    value_loss           | 7.1e+05      |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | 5.04e+03   |
# | time/                   |            |
# |    fps                  | 330        |
# |    iterations           | 13         |
# |    time_elapsed         | 80         |
# |    total_timesteps      | 26624      |
# | train/                  |            |
# |    approx_kl            | 0.00055979 |
# |    clip_fraction        | 0          |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.14      |
# |    explained_variance   | 0.0716     |
# |    learning_rate        | 0.00025    |
# |    loss                 | 4.02e+05   |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.00106   |
# |    value_loss           | 8.01e+05   |
# ----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 5.04e+03      |
# | time/                   |               |
# |    fps                  | 326           |
# |    iterations           | 14            |
# |    time_elapsed         | 87            |
# |    total_timesteps      | 28672         |
# | train/                  |               |
# |    approx_kl            | 0.00023003775 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.14         |
# |    explained_variance   | 0.0368        |
# |    learning_rate        | 0.00025       |
# |    loss                 | 4.58e+05      |
# |    n_updates            | 130           |
# |    policy_gradient_loss | -0.000364     |
# |    value_loss           | 8.46e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 4.78e+03      |
# | time/                   |               |
# |    fps                  | 322           |
# |    iterations           | 15            |
# |    time_elapsed         | 95            |
# |    total_timesteps      | 30720         |
# | train/                  |               |
# |    approx_kl            | 0.00015986987 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.15         |
# |    explained_variance   | 0.0336        |
# |    learning_rate        | 0.00025       |
# |    loss                 | 4.04e+05      |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -0.000122     |
# |    value_loss           | 7.79e+05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 4.85e+03     |
# | time/                   |              |
# |    fps                  | 319          |
# |    iterations           | 16           |
# |    time_elapsed         | 102          |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0001299645 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | 0.0572       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 3.44e+05     |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.000448    |
# |    value_loss           | 9.58e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 4.91e+03      |
# | time/                   |               |
# |    fps                  | 317           |
# |    iterations           | 17            |
# |    time_elapsed         | 109           |
# |    total_timesteps      | 34816         |
# | train/                  |               |
# |    approx_kl            | 4.4296496e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.16         |
# |    explained_variance   | 0.0692        |
# |    learning_rate        | 0.00025       |
# |    loss                 | 5.76e+05      |
# |    n_updates            | 160           |
# |    policy_gradient_loss | -9.11e-05     |
# |    value_loss           | 9.25e+05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 5e+03        |
# | time/                   |              |
# |    fps                  | 317          |
# |    iterations           | 18           |
# |    time_elapsed         | 116          |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0031948308 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.11        |
# |    explained_variance   | 0.0158       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 3.95e+05     |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00416     |
# |    value_loss           | 7.72e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 5.17e+03     |
# | time/                   |              |
# |    fps                  | 316          |
# |    iterations           | 19           |
# |    time_elapsed         | 123          |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0002705217 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.11        |
# |    explained_variance   | 0.0716       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 4.7e+05      |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.000264    |
# |    value_loss           | 8.77e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 5.47e+03     |
# | time/                   |              |
# |    fps                  | 314          |
# |    iterations           | 20           |
# |    time_elapsed         | 130          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0019142474 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0.0539       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 4.57e+05     |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00289     |
# |    value_loss           | 9.08e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 5.68e+03     |
# | time/                   |              |
# |    fps                  | 312          |
# |    iterations           | 21           |
# |    time_elapsed         | 137          |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0014287569 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.0582       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 5.44e+05     |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.000649    |
# |    value_loss           | 9.13e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 5.38e+03      |
# | time/                   |               |
# |    fps                  | 311           |
# |    iterations           | 22            |
# |    time_elapsed         | 144           |
# |    total_timesteps      | 45056         |
# | train/                  |               |
# |    approx_kl            | 0.00017138978 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.11         |
# |    explained_variance   | 0.103         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 3.6e+05       |
# |    n_updates            | 210           |
# |    policy_gradient_loss | -0.000262     |
# |    value_loss           | 8.3e+05       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 5.39e+03     |
# | time/                   |              |
# |    fps                  | 310          |
# |    iterations           | 23           |
# |    time_elapsed         | 151          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0013182313 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.12        |
# |    explained_variance   | 0.129        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 3.41e+05     |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00198     |
# |    value_loss           | 7.54e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 5.11e+03     |
# | time/                   |              |
# |    fps                  | 309          |
# |    iterations           | 24           |
# |    time_elapsed         | 159          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0003283146 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.0887       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 4.69e+05     |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.000678    |
# |    value_loss           | 8.87e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 5.45e+03    |
# | time/                   |             |
# |    fps                  | 308         |
# |    iterations           | 25          |
# |    time_elapsed         | 166         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.000512743 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.0885      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 5.06e+05    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -6.57e-05   |
# |    value_loss           | 1.12e+06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 5.41e+03     |
# | time/                   |              |
# |    fps                  | 307          |
# |    iterations           | 26           |
# |    time_elapsed         | 173          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0029121772 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0.0372       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 4.84e+05     |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00501     |
# |    value_loss           | 9.6e+05      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 5.74e+03      |
# | time/                   |               |
# |    fps                  | 305           |
# |    iterations           | 27            |
# |    time_elapsed         | 180           |
# |    total_timesteps      | 55296         |
# | train/                  |               |
# |    approx_kl            | 7.3302945e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.02         |
# |    explained_variance   | 0.087         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 5.34e+05      |
# |    n_updates            | 260           |
# |    policy_gradient_loss | 8.95e-05      |
# |    value_loss           | 1.15e+06      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 5.67e+03    |
# | time/                   |             |
# |    fps                  | 305         |
# |    iterations           | 28          |
# |    time_elapsed         | 187         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.001389367 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.992      |
# |    explained_variance   | 0.137       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 5.17e+05    |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00211    |
# |    value_loss           | 9.53e+05    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 5.82e+03      |
# | time/                   |               |
# |    fps                  | 306           |
# |    iterations           | 29            |
# |    time_elapsed         | 193           |
# |    total_timesteps      | 59392         |
# | train/                  |               |
# |    approx_kl            | 0.00022529857 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.02         |
# |    explained_variance   | 0.118         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 5.07e+05      |
# |    n_updates            | 280           |
# |    policy_gradient_loss | -1.5e-05      |
# |    value_loss           | 8.92e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 5.84e+03      |
# | time/                   |               |
# |    fps                  | 308           |
# |    iterations           | 30            |
# |    time_elapsed         | 199           |
# |    total_timesteps      | 61440         |
# | train/                  |               |
# |    approx_kl            | 0.00019150268 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.995        |
# |    explained_variance   | 0.135         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 5.23e+05      |
# |    n_updates            | 290           |
# |    policy_gradient_loss | -0.000563     |
# |    value_loss           | 9.97e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 6.14e+03      |
# | time/                   |               |
# |    fps                  | 304           |
# |    iterations           | 31            |
# |    time_elapsed         | 208           |
# |    total_timesteps      | 63488         |
# | train/                  |               |
# |    approx_kl            | 0.00046764594 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.948        |
# |    explained_variance   | 0.0268        |
# |    learning_rate        | 0.00025       |
# |    loss                 | 4.89e+05      |
# |    n_updates            | 300           |
# |    policy_gradient_loss | -0.00119      |
# |    value_loss           | 9.99e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 6.31e+03      |
# | time/                   |               |
# |    fps                  | 302           |
# |    iterations           | 32            |
# |    time_elapsed         | 216           |
# |    total_timesteps      | 65536         |
# | train/                  |               |
# |    approx_kl            | 0.00011157326 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.945        |
# |    explained_variance   | 0.14          |
# |    learning_rate        | 0.00025       |
# |    loss                 | 5.66e+05      |
# |    n_updates            | 310           |
# |    policy_gradient_loss | -0.000405     |
# |    value_loss           | 1.17e+06      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 6.23e+03     |
# | time/                   |              |
# |    fps                  | 299          |
# |    iterations           | 33           |
# |    time_elapsed         | 225          |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0002477218 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.943       |
# |    explained_variance   | 0.00441      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 5.57e+05     |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.000123    |
# |    value_loss           | 1.06e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 6.55e+03     |
# | time/                   |              |
# |    fps                  | 298          |
# |    iterations           | 34           |
# |    time_elapsed         | 233          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0006322117 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.15         |
# |    learning_rate        | 0.00025      |
# |    loss                 | 5.1e+05      |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -8.09e-05    |
# |    value_loss           | 9.1e+05      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 6.06e+03    |
# | time/                   |             |
# |    fps                  | 296         |
# |    iterations           | 35          |
# |    time_elapsed         | 241         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.003612369 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.907      |
# |    explained_variance   | 3.06e-05    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 5.79e+05    |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00461    |
# |    value_loss           | 1.13e+06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 5.96e+03     |
# | time/                   |              |
# |    fps                  | 296          |
# |    iterations           | 36           |
# |    time_elapsed         | 249          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 9.630778e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.992       |
# |    explained_variance   | 0.104        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 3.64e+05     |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -4.55e-05    |
# |    value_loss           | 1.18e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 5.9e+03      |
# | time/                   |              |
# |    fps                  | 295          |
# |    iterations           | 37           |
# |    time_elapsed         | 256          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 9.398465e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.937       |
# |    explained_variance   | 0.166        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 6.49e+05     |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.000312    |
# |    value_loss           | 1.15e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 5.93e+03     |
# | time/                   |              |
# |    fps                  | 294          |
# |    iterations           | 38           |
# |    time_elapsed         | 264          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 4.683534e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.941       |
# |    explained_variance   | 0.206        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 5.09e+05     |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.000194    |
# |    value_loss           | 1.06e+06     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 5.65e+03      |
# | time/                   |               |
# |    fps                  | 293           |
# |    iterations           | 39            |
# |    time_elapsed         | 272           |
# |    total_timesteps      | 79872         |
# | train/                  |               |
# |    approx_kl            | 0.00080624805 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.95         |
# |    explained_variance   | 0.176         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 4.31e+05      |
# |    n_updates            | 380           |
# |    policy_gradient_loss | -0.00162      |
# |    value_loss           | 9.73e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 6.09e+03      |
# | time/                   |               |
# |    fps                  | 293           |
# |    iterations           | 40            |
# |    time_elapsed         | 279           |
# |    total_timesteps      | 81920         |
# | train/                  |               |
# |    approx_kl            | 0.00010657136 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.89         |
# |    explained_variance   | 0.103         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 7.98e+05      |
# |    n_updates            | 390           |
# |    policy_gradient_loss | -5.59e-05     |
# |    value_loss           | 1.49e+06      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 6.41e+03     |
# | time/                   |              |
# |    fps                  | 292          |
# |    iterations           | 41           |
# |    time_elapsed         | 286          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 8.425521e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.885       |
# |    explained_variance   | 0.204        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 5.33e+05     |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -8.94e-05    |
# |    value_loss           | 1.12e+06     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 6.19e+03      |
# | time/                   |               |
# |    fps                  | 291           |
# |    iterations           | 42            |
# |    time_elapsed         | 294           |
# |    total_timesteps      | 86016         |
# | train/                  |               |
# |    approx_kl            | 0.00025209328 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.896        |
# |    explained_variance   | 0.114         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 5.94e+05      |
# |    n_updates            | 410           |
# |    policy_gradient_loss | 4.01e-05      |
# |    value_loss           | 1.17e+06      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 6.5e+03       |
# | time/                   |               |
# |    fps                  | 289           |
# |    iterations           | 43            |
# |    time_elapsed         | 304           |
# |    total_timesteps      | 88064         |
# | train/                  |               |
# |    approx_kl            | 3.2216543e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.941        |
# |    explained_variance   | 0.14          |
# |    learning_rate        | 0.00025       |
# |    loss                 | 5.81e+05      |
# |    n_updates            | 420           |
# |    policy_gradient_loss | -4.95e-05     |
# |    value_loss           | 1.45e+06      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 6.62e+03     |
# | time/                   |              |
# |    fps                  | 288          |
# |    iterations           | 44           |
# |    time_elapsed         | 312          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0003837441 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.914       |
# |    explained_variance   | 0.0682       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 5.29e+05     |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.000945    |
# |    value_loss           | 1.13e+06     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 6.68e+03      |
# | time/                   |               |
# |    fps                  | 287           |
# |    iterations           | 45            |
# |    time_elapsed         | 320           |
# |    total_timesteps      | 92160         |
# | train/                  |               |
# |    approx_kl            | 1.8919236e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.903        |
# |    explained_variance   | 0.0778        |
# |    learning_rate        | 0.00025       |
# |    loss                 | 5.65e+05      |
# |    n_updates            | 440           |
# |    policy_gradient_loss | -3.87e-05     |
# |    value_loss           | 1.05e+06      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 6.69e+03     |
# | time/                   |              |
# |    fps                  | 287          |
# |    iterations           | 46           |
# |    time_elapsed         | 328          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0011468233 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.868       |
# |    explained_variance   | 0.0506       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 5.12e+05     |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00195     |
# |    value_loss           | 1.11e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 6.68e+03     |
# | time/                   |              |
# |    fps                  | 286          |
# |    iterations           | 47           |
# |    time_elapsed         | 335          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0005860892 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.918       |
# |    explained_variance   | 0.153        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 4.6e+05      |
# |    n_updates            | 460          |
# |    policy_gradient_loss | 1.94e-05     |
# |    value_loss           | 9.92e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 6.59e+03      |
# | time/                   |               |
# |    fps                  | 287           |
# |    iterations           | 48            |
# |    time_elapsed         | 342           |
# |    total_timesteps      | 98304         |
# | train/                  |               |
# |    approx_kl            | 0.00016201648 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.907        |
# |    explained_variance   | 0.182         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 5.32e+05      |
# |    n_updates            | 470           |
# |    policy_gradient_loss | -0.000513     |
# |    value_loss           | 1.13e+06      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 6.54e+03     |
# | time/                   |              |
# |    fps                  | 287          |
# |    iterations           | 49           |
# |    time_elapsed         | 348          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0007842287 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.893       |
# |    explained_variance   | 0.0405       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 6.49e+05     |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -9.57e-05    |
# |    value_loss           | 1.1e+06      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 6.29e+03     |
# | time/                   |              |
# |    fps                  | 287          |
# |    iterations           | 50           |
# |    time_elapsed         | 356          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0005189131 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.925       |
# |    explained_variance   | 0.115        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 4.13e+05     |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00012     |
# |    value_loss           | 9.83e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 6.2e+03      |
# | time/                   |              |
# |    fps                  | 287          |
# |    iterations           | 51           |
# |    time_elapsed         | 363          |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0002712481 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.938       |
# |    explained_variance   | 0.152        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 5.62e+05     |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00048     |
# |    value_loss           | 1.11e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 6.36e+03     |
# | time/                   |              |
# |    fps                  | 287          |
# |    iterations           | 52           |
# |    time_elapsed         | 370          |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0010462133 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.961       |
# |    explained_variance   | 0.218        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 4.69e+05     |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.00021     |
# |    value_loss           | 1.04e+06     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 6.37e+03      |
# | time/                   |               |
# |    fps                  | 286           |
# |    iterations           | 53            |
# |    time_elapsed         | 378           |
# |    total_timesteps      | 108544        |
# | train/                  |               |
# |    approx_kl            | 0.00052189734 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.01         |
# |    explained_variance   | 0.206         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 3.84e+05      |
# |    n_updates            | 520           |
# |    policy_gradient_loss | -0.000191     |
# |    value_loss           | 8.45e+05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# ...
# |    time_elapsed         | 1715          |
# |    total_timesteps      | 471040        |
# | train/                  |               |
# |    approx_kl            | 3.5563164e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.926        |
# |    explained_variance   | 0.365         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 6.5e+05       |
# |    n_updates            | 2290          |
# |    policy_gradient_loss | -0.000179     |
# |    value_loss           | 9.26e+05      |
# -------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 100            |
# |    ep_rew_mean          | 6.39e+03       |
# | time/                   |                |
# |    fps                  | 274            |
# |    iterations           | 231            |
# |    time_elapsed         | 1722           |
# |    total_timesteps      | 473088         |
# | train/                  |                |
# |    approx_kl            | 1.08136155e-05 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -0.966         |
# |    explained_variance   | 0.357          |
# |    learning_rate        | 0.00025        |
# |    loss                 | 3.39e+05       |
# |    n_updates            | 2300           |
# |    policy_gradient_loss | -5.84e-05      |
# |    value_loss           | 7.76e+05       |
# --------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 6.5e+03      |
# | time/                   |              |
# |    fps                  | 274          |
# |    iterations           | 232          |
# |    time_elapsed         | 1729         |
# |    total_timesteps      | 475136       |
# | train/                  |              |
# |    approx_kl            | 4.414469e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.974       |
# |    explained_variance   | 0.405        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 3.79e+05     |
# |    n_updates            | 2310         |
# |    policy_gradient_loss | -9.95e-07    |
# |    value_loss           | 7.11e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 6.36e+03     |
# | time/                   |              |
# |    fps                  | 274          |
# |    iterations           | 233          |
# |    time_elapsed         | 1735         |
# |    total_timesteps      | 477184       |
# | train/                  |              |
# |    approx_kl            | 2.957505e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.936       |
# |    explained_variance   | 0.187        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 4.78e+05     |
# |    n_updates            | 2320         |
# |    policy_gradient_loss | -0.000136    |
# |    value_loss           | 8.1e+05      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 6.13e+03      |
# | time/                   |               |
# |    fps                  | 274           |
# |    iterations           | 234           |
# |    time_elapsed         | 1742          |
# |    total_timesteps      | 479232        |
# | train/                  |               |
# |    approx_kl            | 5.4847333e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.965        |
# |    explained_variance   | 0.479         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 4.04e+05      |
# |    n_updates            | 2330          |
# |    policy_gradient_loss | -4.9e-07      |
# |    value_loss           | 8.03e+05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 6.18e+03     |
# | time/                   |              |
# |    fps                  | 275          |
# |    iterations           | 235          |
# |    time_elapsed         | 1749         |
# |    total_timesteps      | 481280       |
# | train/                  |              |
# |    approx_kl            | 9.071082e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.989       |
# |    explained_variance   | 0.446        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 3.18e+05     |
# |    n_updates            | 2340         |
# |    policy_gradient_loss | -2.86e-07    |
# |    value_loss           | 6.93e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 6.34e+03      |
# | time/                   |               |
# |    fps                  | 275           |
# |    iterations           | 236           |
# |    time_elapsed         | 1755          |
# |    total_timesteps      | 483328        |
# | train/                  |               |
# |    approx_kl            | 2.4144218e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.935        |
# |    explained_variance   | 0.401         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 4.73e+05      |
# |    n_updates            | 2350          |
# |    policy_gradient_loss | -0.000216     |
# |    value_loss           | 8.41e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 6.14e+03      |
# | time/                   |               |
# |    fps                  | 275           |
# |    iterations           | 237           |
# |    time_elapsed         | 1762          |
# |    total_timesteps      | 485376        |
# | train/                  |               |
# |    approx_kl            | 6.1096536e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.936        |
# |    explained_variance   | 0.207         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 3.72e+05      |
# |    n_updates            | 2360          |
# |    policy_gradient_loss | -0.000433     |
# |    value_loss           | 7.39e+05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 6.13e+03     |
# | time/                   |              |
# |    fps                  | 275          |
# |    iterations           | 238          |
# |    time_elapsed         | 1769         |
# |    total_timesteps      | 487424       |
# | train/                  |              |
# |    approx_kl            | 2.501998e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.968       |
# |    explained_variance   | 0.528        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 4.56e+05     |
# |    n_updates            | 2370         |
# |    policy_gradient_loss | -7.48e-05    |
# |    value_loss           | 8.22e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 6.41e+03     |
# | time/                   |              |
# |    fps                  | 275          |
# |    iterations           | 239          |
# |    time_elapsed         | 1777         |
# |    total_timesteps      | 489472       |
# | train/                  |              |
# |    approx_kl            | 3.752415e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.958       |
# |    explained_variance   | 0.476        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 3.54e+05     |
# |    n_updates            | 2380         |
# |    policy_gradient_loss | -6.98e-05    |
# |    value_loss           | 8.98e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 6.56e+03      |
# | time/                   |               |
# |    fps                  | 275           |
# |    iterations           | 240           |
# |    time_elapsed         | 1784          |
# |    total_timesteps      | 491520        |
# | train/                  |               |
# |    approx_kl            | 0.00024154407 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.897        |
# |    explained_variance   | 0.0969        |
# |    learning_rate        | 0.00025       |
# |    loss                 | 4.24e+05      |
# |    n_updates            | 2390          |
# |    policy_gradient_loss | -0.000546     |
# |    value_loss           | 8.56e+05      |
# -------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 100            |
# |    ep_rew_mean          | 6.43e+03       |
# | time/                   |                |
# |    fps                  | 275            |
# |    iterations           | 241            |
# |    time_elapsed         | 1791           |
# |    total_timesteps      | 493568         |
# | train/                  |                |
# |    approx_kl            | 0.000104762206 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -0.896         |
# |    explained_variance   | 0.107          |
# |    learning_rate        | 0.00025        |
# |    loss                 | 3.67e+05       |
# |    n_updates            | 2400           |
# |    policy_gradient_loss | -0.00037       |
# |    value_loss           | 8.32e+05       |
# --------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 6.55e+03     |
# | time/                   |              |
# |    fps                  | 275          |
# |    iterations           | 242          |
# |    time_elapsed         | 1799         |
# |    total_timesteps      | 495616       |
# | train/                  |              |
# |    approx_kl            | 7.832007e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.915       |
# |    explained_variance   | 0.284        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 3.71e+05     |
# |    n_updates            | 2410         |
# |    policy_gradient_loss | 5.17e-05     |
# |    value_loss           | 7.52e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 6.41e+03      |
# | time/                   |               |
# |    fps                  | 275           |
# |    iterations           | 243           |
# |    time_elapsed         | 1805          |
# |    total_timesteps      | 497664        |
# | train/                  |               |
# |    approx_kl            | 1.7684477e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.936        |
# |    explained_variance   | 0.396         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 4.23e+05      |
# |    n_updates            | 2420          |
# |    policy_gradient_loss | 2.52e-05      |
# |    value_loss           | 8.36e+05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 5.98e+03     |
# | time/                   |              |
# |    fps                  | 275          |
# |    iterations           | 244          |
# |    time_elapsed         | 1812         |
# |    total_timesteps      | 499712       |
# | train/                  |              |
# |    approx_kl            | 9.325449e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.986       |
# |    explained_variance   | 0.583        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 3.04e+05     |
# |    n_updates            | 2430         |
# |    policy_gradient_loss | -1.88e-05    |
# |    value_loss           | 7.97e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 5.84e+03      |
# | time/                   |               |
# |    fps                  | 275           |
# |    iterations           | 245           |
# |    time_elapsed         | 1819          |
# |    total_timesteps      | 501760        |
# | train/                  |               |
# |    approx_kl            | 1.0514108e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.97         |
# |    explained_variance   | 0.525         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 3.78e+05      |
# |    n_updates            | 2440          |
# |    policy_gradient_loss | -2.2e-06      |
# |    value_loss           | 9.16e+05      |
# -------------------------------------------
# ✅ Pelatihan selesai. Model disimpan: hybrid_4bitrate_ndn_model_v3
#   📊 Plot disimpan: ./rl_logs_4bitrate/eval_4bitrate_report_foot_0001.log.png
#   [report_foot_0001.log] Avg Bitrate: 3.30 Mbps | Total Stalling: 9.23s | Distribusi: {'720p': 95, '480p': 3, '360p': 2}
#   📊 Plot disimpan: ./rl_logs_4bitrate/eval_4bitrate_report_foot_0002.log.png
#   [report_foot_0002.log] Avg Bitrate: 3.26 Mbps | Total Stalling: 358.83s | Distribusi: {'720p': 93, '480p': 5, '360p': 2}
#   📊 Plot disimpan: ./rl_logs_4bitrate/eval_4bitrate_report_foot_0003.log.png
#   [report_foot_0003.log] Avg Bitrate: 3.11 Mbps | Total Stalling: 15.11s | Distribusi: {'720p': 87, '360p': 9, '480p': 4}
#   📊 Plot disimpan: ./rl_logs_4bitrate/eval_4bitrate_report_foot_0004.log.png
#   [report_foot_0004.log] Avg Bitrate: 3.38 Mbps | Total Stalling: 19.70s | Distribusi: {'720p': 99, '480p': 1}
#   📊 Plot disimpan: ./rl_logs_4bitrate/eval_4bitrate_report_foot_0005.log.png
#   [report_foot_0005.log] Avg Bitrate: 3.38 Mbps | Total Stalling: 51.12s | Distribusi: {'720p': 99, '480p': 1}
#   📊 Plot disimpan: ./rl_logs_4bitrate/eval_4bitrate_report_foot_0006.log.png
#   [report_foot_0006.log] Avg Bitrate: 3.28 Mbps | Total Stalling: 73.27s | Distribusi: {'720p': 94, '480p': 4, '360p': 2}
#   📊 Plot disimpan: ./rl_logs_4bitrate/eval_4bitrate_report_foot_0007.log.png
#   [report_foot_0007.log] Avg Bitrate: 3.18 Mbps | Total Stalling: 92.06s | Distribusi: {'720p': 87, '480p': 13}
#   📊 Plot disimpan: ./rl_logs_4bitrate/eval_4bitrate_report_foot_0008.log.png
#   [report_foot_0008.log] Avg Bitrate: 2.76 Mbps | Total Stalling: 105.67s | Distribusi: {'720p': 65, '480p': 30, '360p': 5}

# %%
print("Hi")
# Out:
# Hi
